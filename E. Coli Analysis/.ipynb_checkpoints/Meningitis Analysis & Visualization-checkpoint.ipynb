# %% [markdown]
# # Meningitis
# Infection Rates Over Time Compared In A Variety of Ways

# %%
# importing dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# Meningitis data file
meningitis_data_df = "Resources/Meningitis_Data.csv"

# %%
# Read the Meningitis data 
meningitis_data_df = "Resources/Meningitis_Data.csv"
meningitis_df = pd.read_csv(meningitis_data_df)

# %%
# Display the data table for preview
meningitis_df.head()
# Out:
#    Year  Value                                      Units  \
# 0  1997   1.44  Per 100,000 population (excluding Oregon)
# 1  1997   1.61  Per 100,000 population (excluding Oregon)
# 2  1997   0.46  Per 100,000 population (excluding Oregon)
# 3  1997   1.16  Per 100,000 population (excluding Oregon)
# 4  1997   4.23  Per 100,000 population (excluding Oregon)
#
#                  Bacteria       Topic ViewBy          ViewBy2
# 0  Neisseria meningitidis  Case rates    Age  11-17 years old
# 1  Neisseria meningitidis  Case rates    Age  18-22 years old
# 2  Neisseria meningitidis  Case rates    Age  23-49 years old
# 3  Neisseria meningitidis  Case rates    Age   5-10 years old
# 4  Neisseria meningitidis  Case rates    Age     <5 years old

# %% [markdown]
# US Infection Rates Over Time

# %%
# Set new index to 'Year'

df = meningitis_df.set_index("Year")
df.head()
# Out:
#       Value                                      Units  \
# Year
# 1997   1.44  Per 100,000 population (excluding Oregon)
# 1997   1.61  Per 100,000 population (excluding Oregon)
# 1997   0.46  Per 100,000 population (excluding Oregon)
# 1997   1.16  Per 100,000 population (excluding Oregon)
# 1997   4.23  Per 100,000 population (excluding Oregon)
#
#                     Bacteria       Topic ViewBy          ViewBy2
# Year
# 1997  Neisseria meningitidis  Case rates    Age  11-17 years old
# 1997  Neisseria meningitidis  Case rates    Age  18-22 years old
# 1997  Neisseria meningitidis  Case rates    Age  23-49 years old
# 1997  Neisseria meningitidis  Case rates    Age   5-10 years old
# 1997  Neisseria meningitidis  Case rates    Age     <5 years old

# %%
meningitis_df.dtypes
# Out:
# Year          int64
# Value       float64
# Units        object
# Bacteria     object
# Topic        object
# ViewBy       object
# ViewBy2      object
# dtype: object

# %%
for x in meningitis_df.columns:
    print ("----------------------")
    print (x)
    print (meningitis_df[x].value_counts())
# Out:
# ----------------------
# Year
# 1997    27
# 1998    27
# 2019    27
# 2018    27
# 2017    27
# 2016    27
# 2015    27
# 2014    27
# 2013    27
# 2012    27
# 2011    27
# 2010    27
# 2009    27
# 2008    27
# 2007    27
# 2006    27
# 2005    27
# 2004    27
# 2003    27
# 2002    27
# 2001    27
# 2000    27
# 1999    27
# 2020    27
# Name: Year, dtype: int64
# ----------------------
# Value
# 0.030       26
# 0.100       22
# 0.200       19
# 0.160       18
# 0.080       16
#             ..
# 0.495        1
# 0.480        1
# 1.730        1
# 1664.000     1
# 0.529        1
# Name: Value, Length: 235, dtype: int64
# ----------------------
# Units
# Per 100,000 population                       312
# Per 100,000 population (excluding Oregon)    168
# Counts                                        96
# Percent                                       72
# Name: Units, dtype: int64
# ----------------------
# Bacteria
# Neisseria meningitidis    648
# Name: Bacteria, dtype: int64
# ----------------------
# Topic
# Case rates                    360
# Number of Cases and Deaths     96
# Serogroups                     96
# Syndromes                      72
# Death rates                    24
# Name: Topic, dtype: int64
# ----------------------
# ViewBy
# Age        168
# All        160
# Race        96
# Sex         72
# Overall     48
# B           24
# C           24
# Other       24
# Y           24
# ALL          8
# Name: ViewBy, dtype: int64
# ----------------------
# ViewBy2
# Overall                      72
# 11-17 years old              24
# 18-22 years old              24
# Meningitis                   24
# Bacteremia without focus     24
# Bacteremia with pneumonia    24
# Total cases                  24
# Number of survivals          24
# Number of deaths             24
# Male                         24
# Female                       24
# White                        24
# Other races                  24
# Black                        24
# ≥50 years old                24
# <5 years old                 24
# 5-10 years old               24
# 23-49 years old              24
# NNDSS Total cases†           22
# NNDSS Total cases             2
# Name: ViewBy2, dtype: int64

# %%
#checking for n/as
meningitis_df.isnull().sum()
# Out:
# Year          0
# Value         0
# Units         0
# Bacteria      0
# Topic         0
# ViewBy        0
# ViewBy2     144
# dtype: int64

# %%
#check for duplicates
#look into this more
duplicates_df=meningitis_df[meningitis_df.duplicated()]
duplicates_df
# Out:
# Empty DataFrame
# Columns: [Year, Value, Units, Bacteria, Topic, ViewBy, ViewBy2]
# Index: []

# %%
meningitis_2018=meningitis_df[meningitis_df["Year"]==2018]
meningitis_2019=meningitis_df[meningitis_df["Year"]==2019]
meningitis_2020=meningitis_df[meningitis_df["Year"]==2020]

meningitis_year=meningitis_df.groupby(["Year"]).agg({"ViewBy" :["sum"]})

# Filter the DataFrame down only to those columns to chart
meningitis_df = meningitis_df[["Year", "Value"]]

# Set the index to be "Year" so they will be used as labels
#meningitis_df = meningitis_df.set_index("Year")

meningitis_2020.head()
# Out:
#      Year  Value                                      Units  \
# 621  2020   0.03  Per 100,000 population (excluding Oregon)
# 622  2020   0.10  Per 100,000 population (excluding Oregon)
# 623  2020   0.05  Per 100,000 population (excluding Oregon)
# 624  2020   0.06  Per 100,000 population (excluding Oregon)
# 625  2020   0.27  Per 100,000 population (excluding Oregon)
#
#                    Bacteria       Topic ViewBy          ViewBy2
# 621  Neisseria meningitidis  Case rates    Age  11-17 years old
# 622  Neisseria meningitidis  Case rates    Age  18-22 years old
# 623  Neisseria meningitidis  Case rates    Age  23-49 years old
# 624  Neisseria meningitidis  Case rates    Age   5-10 years old
# 625  Neisseria meningitidis  Case rates    Age     <5 years old

# %%
#checking for value counts in 2020 data for overall illness counts
#how do you call ViewBy, Overall?
meningitis_2020[0].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 #checking for number of months in 2020 data
# ----> 2 meningitis_2020[0].value_counts()
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
#display all column names of DataFrame
#print(df.columns.tolist())

#['Year', 'Value', 'Topic', 'ViewBy']

# %%
# locate total cases by 'Year' in the 'Value' column

total_cases = meningitis_df.iloc [:,:2]
total_cases
#print("Using Loc: " + total_cases)
# Out:
#      Year  Value
# 0    1997  1.440
# 1    1997  1.610
# 2    1997  0.460
# 3    1997  1.160
# 4    1997  4.230
# ..    ...    ...
# 643  2020  0.020
# 644  2020  0.030
# 645  2020  0.088
# 646  2020  0.235
# 647  2020  0.529
#
# [648 rows x 2 columns]

# %%
# Read Dataframe rows only from Topic: case rates and ViewBy: Overall

meningitis_2018=meningitis_df[meningitis_df["Year"]==2018]
meningitis_2019=meningitis_df[meningitis_df["Year"]==2019]
meningitis_2020=meningitis_df[meningitis_df["Year"]==2020]
meningitis_2021=meningitis_df[meningitis_df["Year"]==2021]

meningitis_year=meningitis_df.groupby(["Year"]).agg({"Value":["sum"]})

# Filter the DataFrame down only to those columns to chart
meningitis_df = meningitis_df[["Year","Value", "State", "Topic", "ViewBy"]]

# Set the index to be "Year" so they will be used as labels
meningitis_df = meningitis_df.set_index("Year")

meningitis_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 11>()
#       8 meningitis_year=meningitis_df.groupby(["Year"]).agg({"Value":["sum"]})
#      10 # Filter the DataFrame down only to those columns to chart
# ---> 11 meningitis_df = meningitis_df[["Year","Value", "State", "Topic", "ViewBy"]]
#      13 # Set the index to be "Year" so they will be used as labels
#      14 meningitis_df = meningitis_df.set_index("Year")
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['State', 'Topic', 'ViewBy'] not in index"

# %%
#aggregating by year AND overall cases

meningitis_year_and_overall_cases=meningitis_df.groupby(["Year", "Value"]).agg({"Topic":["Overall"]})
meningitis_year_and_overall_cases.reset_index()
meningitis_year_and_overall_cases
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 #aggregating by year AND overall cases
# ----> 3 meningitis_year_and_overall_cases=meningitis_df.groupby(["Year", "Value"]).agg({"Topic":["Overall"]})
#       4 meningitis_year_and_overall_cases.reset_index()
#       5 meningitis_year_and_overall_cases
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/apply.py:467, in Apply.agg_dict_like(self)
#     464     selected_obj = obj._selected_obj
#     465     selection = obj._selection
# --> 467 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#     471     colg = obj._gotitem(selection, ndim=1)
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.8/site-packages/pandas/core/apply.py:585, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     583     if len(cols) > 0:
#     584         cols_sorted = list(safe_sort(list(cols)))
# --> 585         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     587 is_aggregator = lambda x: isinstance(x, (list, tuple, dict))
#     589 # if we have a dict of any non-scalars
#     590 # eg. {'A' : ['mean']}, normalize all to
#     591 # be list-likes
#     592 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Topic'] do not exist"

# %%
from matplotlib import style
style.use('fivethirtyeight')


ax=meningitis_year_and_overall_cases.plot(kind="line", figsize=(20,6))
    # ax.set_xticklabels(meningitis_year_and_overall["Year", "Value", "Overall"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 5>()
#       1 from matplotlib import style
#       2 style.use('fivethirtyeight')
# ----> 5 ax=meningitis_year_and_overall_cases.plot(kind="line", figsize=(20,6))
#       6     # ax.set_xticklabels(meningitis_year_and_overall["Year", "Value", "Overall"])
#       7 plt.show()
#
# NameError: name 'meningitis_year_and_overall_cases' is not defined

# %%
# Create visualization to display case counts by year overlayed with covid cases
#bar graph? w/ each year containing different colors for each of the 3 types of illness categories and one for covid?

# %% [markdown]
# State Infection Rates
# Top 10 States (with longest masking mandates)
# New York
# Massachusetts
# New Jersey
# Delaware
# Connecticut
# Virginia
# Rhode Island
# Maine
# Michigan
# Illinois
# New Mexico

# %% [markdown]
# State Infection Rates
# Bottom 10 States (with shortest masking mandates)
# Florida
# Georgia
# South Carolina
# Tennessee
# Montana
# Oklahoma
# South Dakota
# Wyoming
# Idaho
# Arizona
