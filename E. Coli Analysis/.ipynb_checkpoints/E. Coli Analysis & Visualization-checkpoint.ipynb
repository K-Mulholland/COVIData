# %% [markdown]
# # E. Coli
# Infection Rates Over Time Compared In A Variety of Ways

# %%
# importing dependencies
# do we need additional dependencies? guessing no?
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from pandas import Series, DataFrame


# E. Coli data files
# should we call in the meningitis and/or covid data files also?  guessing no to keep things simple and organized?  
ecoli_data_df = "Escherichia_Coli_NationalOutbreakPublicDataTool.csv"

# %%
# Read the E. Coli data 
ecoli_df = pd.read_csv(ecoli_data_df)

# Display the data table for preview
ecoli_df.head()
# Out:
#    Year  Month      State Primary Mode                Etiology  \
# 0  2015      1       Ohio         Food  Norovirus Genogroup II
# 1  2015      1   Virginia         Food                     NaN
# 2  2015      1       Ohio         Food  Norovirus Genogroup II
# 3  2015      1       Ohio         Food               Norovirus
# 4  2015      1  Minnesota         Food  Norovirus Genogroup II
#
#   Serotype or Genotype Etiology Status  \
# 0                GII.6       Confirmed
# 1                  NaN             NaN
# 2                GII.6       Confirmed
# 3                  NaN       Suspected
# 4                  NaN       Confirmed
#
#                                              Setting  Illnesses  \
# 0                       Restaurant - Sit-down dining          4
# 1  Restaurant - Sit-down dining; Private home/res...         20
# 2                       Restaurant - Sit-down dining         15
# 3                       Restaurant - Sit-down dining          3
# 4                       Restaurant - Sit-down dining          7
#
#    Hospitalizations  ...  Deaths  Info on Deaths  Food Vehicle  \
# 0               0.0  ...     0.0             4.0           NaN
# 1               0.0  ...     0.0             5.0           NaN
# 2               1.0  ...     0.0             9.0           NaN
# 3               0.0  ...     0.0             3.0           NaN
# 4               0.0  ...     0.0             7.0           NaN
#
#   Food Contaminated Ingredient IFSAC Category Water Exposure  Water Type  \
# 0                          NaN            NaN            NaN         NaN
# 1                          NaN            NaN            NaN         NaN
# 2                          NaN            NaN            NaN         NaN
# 3                          NaN            NaN            NaN         NaN
# 4                          NaN            NaN            NaN         NaN
#
#    Animal Type  Animal Type Specify  Water Status
# 0          NaN                  NaN           NaN
# 1          NaN                  NaN           NaN
# 2          NaN                  NaN           NaN
# 3          NaN                  NaN           NaN
# 4          NaN                  NaN           NaN
#
# [5 rows x 21 columns]

# %%
#check data types of columns using in analysis
ecoli_df.dtypes
# Out:
# Year                              int64
# Month                             int64
# State                            object
# Primary Mode                     object
# Etiology                         object
# Serotype or Genotype             object
# Etiology Status                  object
# Setting                          object
# Illnesses                         int64
# Hospitalizations                float64
# Info on Hospitalizations        float64
# Deaths                          float64
# Info on Deaths                  float64
# Food Vehicle                     object
# Food Contaminated Ingredient     object
# IFSAC Category                   object
# Water Exposure                  float64
# Water Type                      float64
# Animal Type                     float64
# Animal Type Specify             float64
# Water Status                    float64
# dtype: object

# %%
#print data to check for information needed for analysis
for x in ecoli_df.columns:
    print ("----------------------")
    print (x)
    print (ecoli_df[x].value_counts())
# Out:
# ----------------------
# Year
# 2018    1054
# 2015     924
# 2019     873
# 2017     861
# 2016     854
# 2020     299
# Name: Year, dtype: int64
# ----------------------
# Month
# 5     474
# 12    460
# 3     459
# 6     459
# 4     435
# 7     419
# 8     404
# 2     391
# 1     378
# 9     337
# 11    336
# 10    313
# Name: Month, dtype: int64
# ----------------------
# State
# Suspected; Confirmed; Suspected                                                              1
# Suspected; Suspected; Confirmed; Suspected                                                   1
# Suspected; Confirmed; Suspected; Confirmed; Confirmed; Suspected; Suspected; Suspected       1
# Name: Etiology Status, dtype: int64
# ----------------------
# Setting
# Restaurant - Sit-down dining                                                                                                             2028
# Private home/residence                                                                                                                    473
# Restaurant - "Fast-food"(drive up service or pay at counter)                                                                              406
# Caterer (food prepared off-site from where served)                                                                                        334
# Unknown                                                                                                                                   197
#                                                                                                                                          ...
# Other; Restaurant - Buffet                                                                                                                  1
# Caterer (food prepared off-site from where served); Hospital                                                                                1
# Restaurant - Sit-down dining; Banquet Facility (food prepared and served on-site); Caterer (food prepared off-site from where served)       1
# Private home/residence; Fair, festival, other temp or mobile services                                                                       1
# Restaurant - Sit-down dining; Long-term care/nursing home/assisted living facility; Hospital; School/college/university                     1
# Name: Setting, Length: 139, dtype: int64
# ----------------------
# Illnesses
# 2      777
# 3      549
# 4      476
# 5      353
# 6      272
#       ...
# 197      1
# 111      1
# 171      1
# 381      1
# 771      1
# Name: Illnesses, Length: 178, dtype: int64
# ----------------------
# Hospitalizations
# 0.0      3575
# 1.0       511
# 2.0       229
# 3.0       129
# 4.0        77
# 5.0        41
# 6.0        29
# 7.0        28
# 10.0       20
# 11.0       19
# 9.0        15
# 8.0        15
# 12.0        9
# 18.0        7
# 13.0        7
# 14.0        6
# 28.0        5
# 16.0        4
# 31.0        4
# 17.0        4
# 29.0        3
# 24.0        3
# 15.0        3
# 22.0        3
# 25.0        3
# 20.0        2
# 30.0        2
# 54.0        2
# 19.0        2
# 27.0        2
# 45.0        2
# 26.0        1
# 37.0        1
# 133.0       1
# 72.0        1
# 124.0       1
# 41.0        1
# 34.0        1
# 32.0        1
# 88.0        1
# 167.0       1
# 52.0        1
# 57.0        1
# 35.0        1
# 104.0       1
# 36.0        1
# 94.0        1
# 23.0        1
# 68.0        1
# 43.0        1
# 71.0        1
# 49.0        1
# 204.0       1
# 21.0        1
# 39.0        1
# Name: Hospitalizations, dtype: int64
# ----------------------
# Info on Hospitalizations
# 2.0      767
# 3.0      519
# 4.0      463
# 5.0      335
# 0.0      262
#         ...
# 108.0      1
# 98.0       1
# 101.0      1
# 149.0      1
# 178.0      1
# Name: Info on Hospitalizations, Length: 169, dtype: int64
# ----------------------
# Deaths
# 0.0    4714
# 1.0      69
# 2.0      14
# 3.0       3
# 6.0       1
# 5.0       1
# 4.0       1
# Name: Deaths, dtype: int64
# ----------------------
# Info on Deaths
# 2.0      760
# 3.0      527
# 4.0      462
# 5.0      331
# 6.0      250
#         ...
# 149.0      1
# 92.0       1
# 205.0      1
# 154.0      1
# 178.0      1
# Name: Info on Deaths, Length: 166, dtype: int64
# ----------------------
# Food Vehicle
# oysters, raw                         96
# chicken                              46
# oysters                              28
# pulled pork                          21
# pork                                 21
#                                      ..
# bacon cheeseburger; vegetables        1
# lettuce; slaw, zesty                  1
# potato salad; macaroni salad          1
# appetizers; house salad; desserts     1
# celery                                1
# Name: Food Vehicle, Length: 1013, dtype: int64
# ----------------------
# Food Contaminated Ingredient
# oysters, raw                 63
# chicken                      55
# pork                         35
# fish, baracuda               33
# oysters                      32
#                              ..
# lettuce; salsa                1
# ground beef; ground beef      1
# drink mixes; water; bread     1
# egg; ground beef              1
# coffee                        1
# Name: Food Contaminated Ingredient, Length: 267, dtype: int64
# ----------------------
# IFSAC Category
# Multiple                 793
# Fish                     224
# Mollusks                 153
# Chicken                  135
# Beef                      90
# Dairy                     86
# Pork                      80
# Vegetable Row Crops       59
# Fruits                    56
# Herbs                     52
# Grains-Beans              48
# Turkey                    35
# Eggs                      28
# Other                     27
# Seeded Vegetables         27
# Crustaceans               21
# Unclassifiable            19
# Root/Underground          15
# Fungi                     10
# Nuts-Seeds                10
# Game                       9
# Sprouts                    8
# Other Aquatic Animals      7
# Invalid                    7
# Other Meat                 6
# Other Poultry              4
# Oils-Sugars                1
# Name: IFSAC Category, dtype: int64
# ----------------------
# Water Exposure
# Series([], Name: Water Exposure, dtype: int64)
# ----------------------
# Water Type
# Series([], Name: Water Type, dtype: int64)
# ----------------------
# Animal Type
# Series([], Name: Animal Type, dtype: int64)
# ----------------------
# Animal Type Specify
# Series([], Name: Animal Type Specify, dtype: int64)
# ----------------------
# Water Status
# Series([], Name: Water Status, dtype: int64)

# %%
#checking for n/as
ecoli_df.isnull().sum()
# Out:
# Year                               0
# Month                              0
# State                              0
# Primary Mode                       0
# Etiology                        1040
# Serotype or Genotype            3266
# Etiology Status                 1040
# Setting                           77
# Illnesses                          0
# Hospitalizations                  80
# Info on Hospitalizations          80
# Deaths                            62
# Info on Deaths                    73
# Food Vehicle                    2855
# Food Contaminated Ingredient    4054
# IFSAC Category                  2855
# Water Exposure                  4865
# Water Type                      4865
# Animal Type                     4865
# Animal Type Specify             4865
# Water Status                    4865
# dtype: int64

# %%
#check for duplicates
#look into this more, where are the duplicates?
duplicates_df=ecoli_df[ecoli_df.duplicated()]
duplicates_df
# Out:
#       Year  Month           State Primary Mode                 Etiology  \
# 54    2015      2            Ohio         Food                Norovirus
# 624   2015     12         Florida         Food                      NaN
# 699   2016      1            Ohio         Food                Norovirus
# 852   2015      8      California         Food        Norovirus unknown
# 967   2016      2        Michigan         Food                      NaN
# 1009  2016      2        Michigan         Food                      NaN
# 1029  2016      4           Texas         Food                      NaN
# 1050  2015     12      California         Food        Norovirus unknown
# 1168  2016      4  North Carolina         Food                      NaN
# 1488  2016     12            Ohio         Food                Norovirus
# 1748  2017      3            Ohio         Food                Norovirus
# 1939  2017      2      Washington         Food                Norovirus
# 1942  2017      3      Washington         Food                Norovirus
# 1958  2017      6  South Carolina         Food        Norovirus unknown
# 1978  2016     12      California         Food                      NaN
# 2389  2017      1      California         Food                      NaN
# 2390  2017      5      California         Food                      NaN
# 2459  2017     12        Michigan         Food                      NaN
# 2463  2017     12        Michigan         Food                      NaN
# 2471  2017     10      Washington         Food                Norovirus
# 2552  2017      1      California         Food                      NaN
# 2645  2018      2          Kansas         Food                      NaN
# 2697  2018      3          Kansas         Food                      NaN
# 2842  2017     12      California         Food        Norovirus unknown
# 2645  Restaurant - "Fast-food"(drive up service or p...          2
# 2697                       Restaurant - Sit-down dining          2
# 2842  Caterer (food prepared off-site from where ser...          4
# 2843                       Restaurant - Sit-down dining          3
# 3139                       Restaurant - Sit-down dining          2
# 3148                       Restaurant - Sit-down dining          3
# 3192                       Restaurant - Sit-down dining          2
# 3211                       Restaurant - Sit-down dining          2
# 3391                       Restaurant - Sit-down dining          2
# 3425                       Restaurant - Sit-down dining          4
# 3564                       Restaurant - Sit-down dining          2
# 3571                       Restaurant - Sit-down dining          2
# 3731                       Restaurant - Sit-down dining          2
# 3940                       Restaurant - Sit-down dining          2
# 4146  Restaurant - "Fast-food"(drive up service or p...          2
# 4361  Restaurant - "Fast-food"(drive up service or p...          2
# 4391                                            Unknown          2
# 4411                       Restaurant - Sit-down dining          4
# 4416                       Restaurant - Sit-down dining          3
# 4419                       Restaurant - Sit-down dining          2
# 4600                             Private home/residence          2
#
#       Hospitalizations  ...  Deaths  Info on Deaths           Food Vehicle  \
# 54                 0.0  ...     0.0             3.0                    NaN
# 624                0.0  ...     0.0             2.0                    NaN
# 699                0.0  ...     0.0             3.0                    NaN
# 852                0.0  ...     0.0             4.0                    NaN
# 967                0.0  ...     0.0             3.0                    NaN
# 1009               0.0  ...     0.0             3.0                    NaN
# 1029               0.0  ...     0.0             7.0                    NaN
# 1050               0.0  ...     0.0             2.0                    NaN
# 1168               0.0  ...     0.0            16.0                    NaN
# 1488               0.0  ...     0.0             2.0                    NaN
# 1748               0.0  ...     0.0             2.0                    NaN
# 1939               0.0  ...     0.0             2.0           oysters, raw
# 1942               0.0  ...     0.0             2.0           oysters, raw
# 1958               0.0  ...     0.0             8.0                    NaN
# 1978               0.0  ...     0.0             4.0                    NaN
# 2389               0.0  ...     0.0             2.0                    NaN
# 2390               0.0  ...     0.0             3.0                    NaN
# 2459               0.0  ...     0.0             2.0                    NaN
# 2463               0.0  ...     0.0             5.0                    NaN
# 2471               0.0  ...     0.0             2.0                    NaN
# 2552               0.0  ...     0.0             2.0                    NaN
# 2645               0.0  ...     0.0             2.0                    NaN
# 2697               0.0  ...     0.0             2.0                    NaN
# 2842               0.0  ...     0.0             4.0                    NaN
# 2843               0.0  ...     0.0             3.0                    NaN
# 3139               0.0  ...     0.0             2.0                    NaN
# 3148               0.0  ...     0.0             3.0                    NaN
# 3192               0.0  ...     0.0             2.0                    NaN
# 3211               0.0  ...     0.0             2.0                    NaN
# 3391               0.0  ...     0.0             2.0  cilantro, unspecified
# 3425               0.0  ...     0.0             4.0                    NaN
# 3564               0.0  ...     0.0             2.0                    NaN
# 3571               0.0  ...     0.0             2.0                    NaN
# 3731               0.0  ...     0.0             2.0                    NaN
# 3940               0.0  ...     0.0             2.0           oysters, raw
# 4146               0.0  ...     0.0             2.0                    NaN
# 4361               0.0  ...     0.0             2.0                    NaN
# 4391               0.0  ...     0.0             2.0                    NaN
# 4411               0.0  ...     0.0             4.0                oysters
# 4416               0.0  ...     0.0             3.0                    NaN
# 4419               0.0  ...     0.0             2.0                    NaN
# 3425          NaN                  NaN           NaN
# 3564          NaN                  NaN           NaN
# 3571          NaN                  NaN           NaN
# 3731          NaN                  NaN           NaN
# 3940          NaN                  NaN           NaN
# 4146          NaN                  NaN           NaN
# 4361          NaN                  NaN           NaN
# 4391          NaN                  NaN           NaN
# 4411          NaN                  NaN           NaN
# 4416          NaN                  NaN           NaN
# 4419          NaN                  NaN           NaN
# 4600          NaN                  NaN           NaN
#
# [42 rows x 21 columns]

# %%
#print dataframe grouped by year

ecoli_2018=ecoli_df[ecoli_df["Year"]==2018]
ecoli_2019=ecoli_df[ecoli_df["Year"]==2019]
ecoli_2020=ecoli_df[ecoli_df["Year"]==2020]

ecoli_year=ecoli_df.groupby(["Year"]).agg({"Illnesses":["sum"]})

# Filter the DataFrame down only to those columns to chart
ecoli_df = ecoli_df[["Year","Month", "State", "Illnesses"]]

# Set the index to be "Year" so they will be used as labels
#ecoli_df = ecoli_df.set_index("Year")

ecoli_2020.head()
# Out:
#       Year  Month          State Primary Mode                 Etiology  \
# 4271  2020      1       New York         Food  Clostridium perfringens
# 4273  2020      1  Massachusetts         Food                Norovirus
# 4278  2020      1       Virginia         Food   Norovirus Genogroup II
# 4281  2020      1       New York         Food                      NaN
# 4284  2020      1      Minnesota         Food   Norovirus Genogroup II
#
#      Serotype or Genotype Etiology Status  \
# 4271                  NaN       Suspected
# 4273                  NaN       Suspected
# 4278           GII.P16 -        Suspected
# 4281                  NaN             NaN
# 4284           GII.P16 -        Confirmed
#
#                                                 Setting  Illnesses  \
# 4271  Caterer (food prepared off-site from where ser...          7
# 4273                       Restaurant - Sit-down dining          9
# 4278                       Restaurant - Sit-down dining          3
# 4281                                      Grocery store          3
# 4284                       Restaurant - Sit-down dining          8
#
#       Hospitalizations  ...  Deaths  Info on Deaths  \
# 4271               0.0  ...     0.0             7.0
# 4273               0.0  ...     0.0             9.0
# 4278               0.0  ...     0.0             0.0
# 4281               0.0  ...     0.0             3.0
# 4284               0.0  ...     0.0             8.0
#
#                                            Food Vehicle  \
# 4271  curry chicken; pelau dish; curry chick peas w/...
# 4273                                                NaN
# 4278                                        raw oysters
# 4281                                                NaN
# 4284                                                NaN
#
#                    Food Contaminated Ingredient IFSAC Category Water Exposure  \
# 4271  chicken; peas; meat; chick peas; potatoes       Multiple            NaN
# 4273                                        NaN            NaN            NaN
# 4278                               oysters, raw       Mollusks            NaN
# 4281                                        NaN            NaN            NaN
# 4284                                        NaN            NaN            NaN
#
#       Water Type  Animal Type  Animal Type Specify  Water Status
# 4271         NaN          NaN                  NaN           NaN
# 4273         NaN          NaN                  NaN           NaN
# 4278         NaN          NaN                  NaN           NaN
# 4281         NaN          NaN                  NaN           NaN
# 4284         NaN          NaN                  NaN           NaN
#
# [5 rows x 21 columns]

# %%
#checking for number of months in 2020 data
ecoli_2020["Month"].value_counts()
# Out:
# 2     49
# 1     44
# 7     36
# 8     30
# 6     24
# 5     20
# 9     20
# 10    19
# 12    16
# 11    15
# 3     14
# 4     12
# Name: Month, dtype: int64

# %%
#aggregating by year AND month

ecoli_year_and_month=ecoli_df.groupby(["Year", "Month"]).agg({"Illnesses":["sum"]})
df=ecoli_year_and_month.reset_index()
df
#ecoli_year_and_month
# Out:
#     Year Month Illnesses
#                      sum
# 0   2015     1       858
# 1   2015     2      1008
# 2   2015     3      1429
# 3   2015     4      1342
# 4   2015     5      1490
# ..   ...   ...       ...
# 67  2020     8       344
# 68  2020     9       205
# 69  2020    10       158
# 70  2020    11       503
# 71  2020    12       262
#
# [72 rows x 3 columns]

# %%
#grouping data by year, month and illness sum

ecoli_2018=df[df["Year"]==2018]
ecoli_2019=df[df["Year"]==2019]
ecoli_2020=df[df["Year"]==2020]

# ecoli_year=ecoli_df.groupby(["Year", "State"]).agg({"Illnesses":["sum"]})

ecoli_2018.columns=["Year", "Month", "Illnesses_Sum"]
ecoli_2019.columns=["Year", "Month", "Illnesses_Sum"]
ecoli_2020.columns=["Year", "Month", "Illnesses_Sum"]


ecoli_2018
#ecoli_year_and_month
# Out:
#     Year  Month  Illnesses_Sum
# 36  2018      1           1394
# 37  2018      2            722
# 38  2018      3           2034
# 39  2018      4           1949
# 40  2018      5           2665
# 41  2018      6           1575
# 42  2018      7           2064
# 43  2018      8           2074
# 44  2018      9            959
# 45  2018     10           1054
# 46  2018     11           1575
# 47  2018     12           1926

# %%
#reseting index so illnesses are summed by year

ecoli_year_df=ecoli_year.reset_index()

ecoli_year_df
# Out:
#    Year Illnesses
#               sum
# 0  2015     15539
# 1  2016     14430
# 2  2017     15059
# 3  2018     19991
# 4  2019     11805
# 5  2020      5987

# %%
#bar graph for comparing e. coli cases by year

plt.xaxis = ['2018', '2019', '2020']

ecoli_year_df.plot.bar('Year', 'Illnesses')
plt.title('E. Coli Cases by Year')
plt.xlabel('Year')
plt.ylabel('Illnesses')
plt.show()

# %%
from matplotlib import style
style.use('fivethirtyeight')

plt.figure(2)
Month=ecoli_2018["Month"]
total_2018=ecoli_2018["Illnesses_Sum"].reset_index(drop=True)
total_2019=ecoli_2019["Illnesses_Sum"].reset_index(drop=True)
total_2020=ecoli_2020["Illnesses_Sum"].reset_index(drop=True)

total_2018.plot.line(x=Month, y=total_2018, label="2018")
total_2019.plot.line(x=Month, y=total_2019, label="2019")
total_2020.plot.line(x=Month, y=total_2020, label="2020")
plt.legend(loc="best")
plt.title('E. Coli Cases by Month')
plt.xlabel("Month of the Year")
plt.ylabel("Number of E. Coli Cases")
plt.xlim(0,12)
plt.ylim(0,2800)
# Out:
# (0.0, 2800.0)

# %%
from matplotlib import style
style.use('fivethirtyeight')

ax=ecoli_year_and_month.plot(kind="line", figsize=(20,6))
    # ax.set_xticklabels(ecoli_year_and_month["Year", "Month"])
plt.title('E. Coli Cases by Month and Year')

plt.show()

# %% [markdown]
# Compare top 10 states (California, Texas, Florida, Illinois, Ohio, Georgia, Pennsylvania, Tennessee, North Carolina, New York) with the most covid cases

# %%
#create a dataframe for 2020 e. coli rates for the state that had the highest covid rates

ecoli_df
ecoli_top=ecoli_df[ecoli_df["Year"]==2020]
ecoli_high=ecoli_top[(ecoli_top["State"]=="California")|(ecoli_top ["State"]=="Texas")\
|(ecoli_top ["State"]=="Florida")|(ecoli_top ["State"]=="Illinois")|(ecoli_top ["State"]=="Ohio")|\
(ecoli_top ["State"]=="Georgia")|(ecoli_top ["State"]=="Pennsylvania")|(ecoli_top ["State"]=="Tennessee")|\
(ecoli_top ["State"]=="North Carolina")|(ecoli_top ["State"]=="New York")]
 
#ecoli_high["Illnesses"].sum()
ecoli_high2=ecoli_high.groupby(["State"]).agg({"Illnesses":["sum"]}).reset_index()
ecoli_high2.columns=["State","Illnesses"]
ecoli_high2
# Out:
#             State  Illnesses
# 0      California        204
# 1         Florida        286
# 2         Georgia         33
# 3        Illinois        194
# 4        New York         22
# 5  North Carolina        236
# 6            Ohio        189
# 7    Pennsylvania         24
# 8       Tennessee        168
# 9           Texas        119

# %%
ecoli_high2.plot.bar()
plt.title('2020 E. Coli Cases for Top 10 States with Highest Covid Rates')
plt.xlabel('State')
plt.ylabel('Illnesses')
plt.show()

# %% [markdown]
# Compare bottom 10 states (Vermont, Hawaii, Maine, Wyoming, Arkansas, New Hampshire, Delaware, Montana, Rhode Island, North Dakota, West Virginia) with the least covid cases

# %%
#create a dataframe for 2020 e. coli rates for the state that had the lowest covid rates


ecoli_bottom=ecoli_df[ecoli_df["Year"]==2020]

ecoli_low=ecoli_bottom[(ecoli_bottom["State"]=="Vermont")|(ecoli_bottom ["State"]=="Hawaii")\
|(ecoli_bottom ["State"]=="Maine")|(ecoli_bottom ["State"]=="Wyoming")|(ecoli_bottom ["State"]=="Arkansas")|\
(ecoli_bottom ["State"]=="New Hampshire")|(ecoli_bottom ["State"]=="Delaware")|(ecoli_bottom ["State"]=="Montana")|\
(ecoli_bottom ["State"]=="Rhode Island")|(ecoli_bottom ["State"]=="North Dakota")|(ecoli_bottom ["State"]=="West Virginia")]

ecoli_low2=ecoli_low.groupby(["State"]).agg({"Illnesses":["sum"]}).reset_index()
ecoli_low2.columns=["State","Illnesses"]
ecoli_low2
# Out:
#            State  Illnesses
# 0         Hawaii         33
# 1          Maine         79
# 2  New Hampshire         19
# 3   North Dakota          8
# 4   Rhode Island         14

# %%
ecoli_low2.plot.bar()
plt.title('2020 E. Coli Cases for Bottom 10 States with Lowest Covid Rates')
plt.xlabel('State')
plt.ylabel('Illnesses')
plt.show()

# %%
#merge low & high dataframes
low_and_high=pd.merge(ecoli_low2, ecoli_high2, on =["Illnesses","State"], how="outer")
# low_and_high.columns=["Illnesses"]

low_and_high
# Out:
#              State  Illnesses
# 0           Hawaii         33
# 1            Maine         79
# 2    New Hampshire         19
# 3     North Dakota          8
# 4     Rhode Island         14
# 5       California        204
# 6          Florida        286
# 7          Georgia         33
# 8         Illinois        194
# 9         New York         22
# 10  North Carolina        236
# 11            Ohio        189
# 12    Pennsylvania         24
# 13       Tennessee        168
# 14           Texas        119

# %%
low_and_high.plot.bar(x='State', y='Illnesses', color=['blue','blue','blue','blue','blue','yellow','yellow','yellow','yellow','yellow','yellow','yellow','yellow','yellow','yellow'])
plt.title('2020 E. Coli Cases/Covid Rates')
plt.xlabel('State')
plt.ylabel('Illnesses')
plt.show()
